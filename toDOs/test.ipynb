# %%
lst = [1,2,3,4,5]
def get_db():
    global lst
    try:
        return lst
    finally:
        lst = []
print(get_db())
print(get_db())
# Out:
# [1, 2, 3, 4, 5]
# []

# %%
from models import Todos
from database import sessionLocal

db = sessionLocal()
new_db = db.query(Todos).all()

# %%
for i in new_db:
    print(i.__dict__)
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BDB97167B0>, 'status': False, 'priority': 2, 'description': 'Milk and eggs', 'title': 'Buy groceries', 'id': 2}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BDBACEF950>, 'status': False, 'priority': 3, 'description': 'Leg day', 'title': 'Go to gym', 'id': 3}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BDBAD802F0>, 'status': True, 'priority': 1, 'description': 'Finish chapter 5', 'title': 'Read book', 'id': 4}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BDBAD80410>, 'status': False, 'priority': 5, 'description': 'Electricity and internet', 'title': 'Pay bills', 'id': 5}
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x000001BDBAD804D0>, 'status': True, 'priority': 2, 'description': 'Vacuum and mop', 'title': 'Clean house', 'id': 6}

# %%
arr = ["'_sa_instance_state"]
for i in new_db:
    dic = i.__dict__
    keys = filter(lambda x : x!= "_sa_instance_state", dic.keys())

    for i in keys:
        print(dic[i])
# Out:
# False
# 2
# Milk and eggs
# Buy groceries
# 2
# False
# 3
# Leg day
# Go to gym
# 3
# True
# 1
# Finish chapter 5
# Read book
# 4
# False
# 5
# Electricity and internet
# Pay bills
# 5
# True
# 2
# Vacuum and mop
# Clean house
# 6

# %%
from typing import Annotated
"""
this answers the usage, and justifies how we are using it in eh sessionlocal
"""
#https://stackoverflow.com/questions/71898644/how-to-use-typing-annotated
a = Annotated[int, 0]
def fun(b:a):
    print(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 def fun(b:a):
#       5     print(b)
# ----> 6 fun()
#
# TypeError: fun() missing 1 required positional argument: 'b'

# %%
import yaml

with open("secrets.yaml", 'r') as file:
    secrets = yaml.safe_load(file)

SECRET_KEY = secrets["SECRET_KEY"]
print(SECRET_KEY)
# Out:
# b78d33d45e8f7826e79bca8ace355fb876b9f8a291b437bca128664ef8e3c298
